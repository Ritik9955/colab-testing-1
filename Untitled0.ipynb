# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritik9955/colab-testing-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ha")
# Out:
# ha

# %%
print("data")
# Out:
# data

# %%
print("123")
